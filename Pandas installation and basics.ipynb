# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\dhrub\\OneDrive\\Desktop\\pandas\\survey_results_public.csv")

# %%
df= df [:10000]
df
# Out:
#       Respondent                                         MainBranch Hobbyist  \
# 0              1                     I am a developer by profession      Yes
# 1              2                     I am a developer by profession       No
# 2              3                        I code primarily as a hobby      Yes
# 3              4                     I am a developer by profession      Yes
# 4              5  I used to be a developer by profession, but no...      Yes
# ...          ...                                                ...      ...
# 9995       10028                     I am a developer by profession      Yes
# 9996       10029                     I am a developer by profession      Yes
# 9997       10030                     I am a developer by profession      Yes
# 9998       10031                     I am a developer by profession       No
# 9999       10032                     I am a developer by profession      Yes
#
# ...

# %% [markdown]
# ## To take the last 10 rows from the data frame

# %%
df.tail(10)
# Out:
#       Respondent                                         MainBranch Hobbyist  \
# 9990       10023                     I am a developer by profession      Yes
# 9991       10024                     I am a developer by profession      Yes
# 9992       10025                     I am a developer by profession       No
# 9993       10026  I am not primarily a developer, but I write co...      Yes
# 9994       10027                     I am a developer by profession      Yes
# 9995       10028                     I am a developer by profession      Yes
# 9996       10029                     I am a developer by profession      Yes
# 9997       10030                     I am a developer by profession      Yes
# 9998       10031                     I am a developer by profession       No
# 9999       10032                     I am a developer by profession      Yes
#
#        Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# ...

# %%
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
# 5           6                     I am a developer by profession       No
# 6           7                     I am a developer by profession      Yes
# 7           8                     I am a developer by profession      Yes
# 8           9                     I am a developer by profession       No
# 9          10                     I am a developer by profession      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# ...

# %% [markdown]
# ## To get the total no. of Rows and Columns in the Data frame

# %%
df.shape
# Out:
# (10000, 61)

# %% [markdown]
# ## Syntax to display the max number of Rows and Columns

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
schema_df =pd.read_csv("C:\\Users\\dhrub\\OneDrive\\Desktop\\pandas\\survey_results_schema.csv")
schema_df
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# ...

# %% [markdown]
# ## To get all the Columns in the Dataframe

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df['Hobbyist']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 9995    Yes
# 9996    Yes
# 9997    Yes
# 9998     No
# 9999    Yes
# Name: Hobbyist, Length: 10000, dtype: object

# %% [markdown]
# ## Using loc to get part of Data frame for specific values by the help of their index values

# %%
df.loc[0:10,'Hobbyist':'Country']
# Out:
#    Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0       Yes   NaN         13  Monthly        NaN            NaN
# 1        No   NaN         19      NaN        NaN            NaN
# 2       Yes   NaN         15      NaN        NaN            NaN
# 3       Yes  25.0         18      NaN        NaN            NaN
# 4       Yes  31.0         16      NaN        NaN            NaN
# 5        No   NaN         14      NaN        NaN            NaN
# 6       Yes   NaN         18  Monthly        NaN            NaN
# 7       Yes  36.0         12   Yearly   116000.0       116000.0
# 8        No  30.0         20      NaN        NaN            NaN
# 9       Yes  22.0         14   Yearly    25000.0        32315.0
# 10      Yes  23.0         13   Yearly    31000.0        40070.0
#
#                Country
# 0              Germany
# 1       United Kingdom
# 2   Russian Federation
# 3              Albania
# 4        United States
# 5              Germany
# 6                India
# ...

# %% [markdown]
# # Updating Data

# %%
df.rename(columns={'CompTotal' : 'SalaryRs'},inplace= True)
df['SalaryRs']
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 9995     1300.0
# 9996    73000.0
# 9997    97500.0
# 9998    73000.0
# 9999        NaN
# Name: SalaryRs, Length: 10000, dtype: float64

# %%
df['Hobbyist']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 9995    Yes
# 9996    Yes
# 9997    Yes
# 9998     No
# 9999    Yes
# Name: Hobbyist, Length: 10000, dtype: object

# %% [markdown]
# ## Converting the yes and no values into True or False of the ' hobbyist ' column

# %%
df['Hobbyist'].map({'Yes':True ,'No':False})
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 9995     True
# 9996     True
# 9997     True
# 9998    False
# 9999     True
# Name: Hobbyist, Length: 10000, dtype: bool

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes':True ,'No':False})
df
# Out:
#       Respondent                                         MainBranch  Hobbyist  \
# 0              1                     I am a developer by profession      True
# 1              2                     I am a developer by profession     False
# 2              3                        I code primarily as a hobby      True
# 3              4                     I am a developer by profession      True
# 4              5  I used to be a developer by profession, but no...      True
# ...          ...                                                ...       ...
# 9995       10028                     I am a developer by profession      True
# 9996       10029                     I am a developer by profession      True
# 9997       10030                     I am a developer by profession      True
# 9998       10031                     I am a developer by profession     False
# 9999       10032                     I am a developer by profession      True
#
# ...
